# %% [markdown]
# # Adding a custom synchronization agent
#
# In the `data/sync_agent_example` an example synchronization agent has been provided that can synchronize datasets with the following file structure:
#
# ```plaintext
# Experiments/
#     ├── 2024_03_05/
#     │   ├── 1/
#     │   │   ├── measurement.txt
#     │   │   └── metadata.json
#     │   └── 2/
#     │       ├── measurement.txt
#     │       └── metadata.json
#     └── 2024_03_06/
#         └── 1/
#             ├── measurement.txt
#             └── metadata.json
# ```
#
# For each set of folders, such as `2024_03_05/1`, `2024_03_05/2`, `2024_03_06/1`, we want to create a dataset.
#
# In the `.txt` files, we expect a one- or two-dimensional dataset. The metadata file is a JSON file that contains some settings of the experiment and the experiment name, which we would like to document. To keep things simple, we assume there are no other files in the folders.
#
# You can download this jupyter notebook and more examples from [here](https://github.com/qEncoder/dataQruiser/tree/main/examples).

# %% [markdown]
# ## Installing the synchronization agent
#
# To install the package we first need to install it:
#
# ```bash
# pip install .
# ```

# %%
# !pip install ./data/sync_agent_example
# Out:
# Processing c:\users\atosato\docs_dataqruiser\code_examples\nqcp\data\sync_agent_example
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: etiket-client in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from file_sync_example==0.1.0) (0.2.29)
# Requirement already satisfied: PyQt5>=5.15.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from etiket-client->file_sync_example==0.1.0) (5.15.11)
# Requirement already satisfied: SQLAlchemy>=2.0.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from etiket-client->file_sync_example==0.1.0) (2.0.35)
# Requirement already satisfied: alembic>=1.6.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from etiket-client->file_sync_example==0.1.0) (1.13.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from etiket-client->file_sync_example==0.1.0) (2.9.1)
# Requirement already satisfied: requests>=2.2.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from etiket-client->file_sync_example==0.1.0) (2.32.3)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from etiket-client->file_sync_example==0.1.0) (4.66.5)
# Requirement already satisfied: urllib3<=2.0.6 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from etiket-client->file_sync_example==0.1.0) (2.0.6)
# Requirement already satisfied: tabulate>=0.8.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from etiket-client->file_sync_example==0.1.0) (0.9.0)
# Requirement already satisfied: filelock>=3.4.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from etiket-client->file_sync_example==0.1.0) (3.16.0)
# Requirement already satisfied: platformdirs>=4.0.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from etiket-client->file_sync_example==0.1.0) (4.3.3)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from etiket-client->file_sync_example==0.1.0) (6.0.0)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from etiket-client->file_sync_example==0.1.0) (2.1.1)
# Requirement already satisfied: PyYAML>=6.0.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from etiket-client->file_sync_example==0.1.0) (6.0.2)
# Requirement already satisfied: email-validator<=2.1.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from etiket-client->file_sync_example==0.1.0) (2.0.0.post2)
# Requirement already satisfied: setproctitle>=1.3.3 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from etiket-client->file_sync_example==0.1.0) (1.3.3)
# Requirement already satisfied: python-dateutil>2.8.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from etiket-client->file_sync_example==0.1.0) (2.9.0.post0)
# Requirement already satisfied: qcodes>0.35.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from etiket-client->file_sync_example==0.1.0) (0.48.0)
# Requirement already satisfied: semantic-version>=2.10.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from etiket-client->file_sync_example==0.1.0) (2.10.0)
# Requirement already satisfied: watchdog>=4.0.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from etiket-client->file_sync_example==0.1.0) (5.0.2)
# Requirement already satisfied: pywin32>=306 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from etiket-client->file_sync_example==0.1.0) (306)
# Requirement already satisfied: xarray>=0.20.2 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from etiket-client->file_sync_example==0.1.0) (2024.9.0)
# Requirement already satisfied: h5py>=3.8.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from etiket-client->file_sync_example==0.1.0) (3.11.0)
# Requirement already satisfied: Mako in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from alembic>=1.6.0->etiket-client->file_sync_example==0.1.0) (1.3.5)
# Requirement already satisfied: typing-extensions>=4 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from alembic>=1.6.0->etiket-client->file_sync_example==0.1.0) (4.12.2)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from email-validator<=2.1.0->etiket-client->file_sync_example==0.1.0) (2.6.1)
# Requirement already satisfied: idna>=2.0.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from email-validator<=2.1.0->etiket-client->file_sync_example==0.1.0) (3.10)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from pydantic<3.0.0,>=2.5.0->etiket-client->file_sync_example==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.3 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from pydantic<3.0.0,>=2.5.0->etiket-client->file_sync_example==0.1.0) (2.23.3)
# Requirement already satisfied: PyQt5-sip<13,>=12.15 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from PyQt5>=5.15.0->etiket-client->file_sync_example==0.1.0) (12.15.0)
# Requirement already satisfied: PyQt5-Qt5<5.16.0,>=5.15.2 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from PyQt5>=5.15.0->etiket-client->file_sync_example==0.1.0) (5.15.2)
# Requirement already satisfied: six>=1.5 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from python-dateutil>2.8.0->etiket-client->file_sync_example==0.1.0) (1.16.0)
# Requirement already satisfied: broadbean>=0.11.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (0.14.0)
# Requirement already satisfied: h5netcdf>=0.14.1 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (1.3.0)
# Requirement already satisfied: ipywidgets<9.0.0,>=8.0.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (8.1.5)
# Requirement already satisfied: ipykernel>=6.6.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (6.29.5)
# Requirement already satisfied: jsonschema>=4.9.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (4.23.0)
# Requirement already satisfied: matplotlib>=3.5.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (3.9.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (24.1)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (2.2.2)
# Requirement already satisfied: pyarrow>=11.0.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (17.0.0)
# Requirement already satisfied: pyvisa<1.15.0,>=1.11.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (1.14.1)
# Requirement already satisfied: ruamel.yaml!=0.16.6,>=0.16.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (0.18.6)
# Requirement already satisfied: uncertainties>=3.1.4 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (3.2.2)
# Requirement already satisfied: versioningit>=2.2.1 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (3.1.2)
# Requirement already satisfied: websockets>=11.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (13.0.1)
# Requirement already satisfied: cf-xarray>=0.8.4 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (0.9.5)
# Requirement already satisfied: opentelemetry-api>=1.15.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (1.27.0)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (10.4.0)
# Requirement already satisfied: dask>=2022.1.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (2024.9.0)
# Requirement already satisfied: tornado>=6.3.3 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (6.4.1)
# Requirement already satisfied: ipython>=8.10.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (8.27.0)
# Requirement already satisfied: wrapt>=1.14.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from requests>=2.2.0->etiket-client->file_sync_example==0.1.0) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from requests>=2.2.0->etiket-client->file_sync_example==0.1.0) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from SQLAlchemy>=2.0.0->etiket-client->file_sync_example==0.1.0) (3.1.0)
# Requirement already satisfied: colorama in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from tqdm>=4.64.0->etiket-client->file_sync_example==0.1.0) (0.4.6)
# Requirement already satisfied: schema in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from broadbean>=0.11.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (0.7.7)
# Requirement already satisfied: click>=8.1 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from dask>=2022.1.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (8.1.7)
# Requirement already satisfied: cloudpickle>=3.0.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from dask>=2022.1.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (3.0.0)
# Requirement already satisfied: fsspec>=2021.09.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from dask>=2022.1.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (2024.9.0)
# Requirement already satisfied: partd>=1.4.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from dask>=2022.1.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (1.4.2)
# Requirement already satisfied: toolz>=0.10.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from dask>=2022.1.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from dask>=2022.1.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (8.4.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from ipykernel>=6.6.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from ipykernel>=6.6.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (1.8.5)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from ipykernel>=6.6.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (8.6.2)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from ipykernel>=6.6.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from ipykernel>=6.6.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from ipykernel>=6.6.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from ipykernel>=6.6.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (26.2.0)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from ipykernel>=6.6.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (5.14.3)
# Requirement already satisfied: decorator in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from ipython>=8.10.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from ipython>=8.10.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from ipython>=8.10.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from ipython>=8.10.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from ipython>=8.10.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (0.6.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from ipywidgets<9.0.0,>=8.0.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from ipywidgets<9.0.0,>=8.0.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (3.0.13)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from jsonschema>=4.9.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from jsonschema>=4.9.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from jsonschema>=4.9.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from jsonschema>=4.9.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (0.20.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from matplotlib>=3.5.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from matplotlib>=3.5.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from matplotlib>=3.5.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from matplotlib>=3.5.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from matplotlib>=3.5.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (3.1.4)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from opentelemetry-api>=1.15.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (1.2.14)
# Requirement already satisfied: pytz>=2020.1 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from pandas>=1.4.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from pandas>=1.4.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (2024.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from ruamel.yaml!=0.16.6,>=0.16.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (0.2.8)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from Mako->alembic>=1.6.0->etiket-client->file_sync_example==0.1.0) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from importlib-metadata>=4.13.0->dask>=2022.1.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (3.20.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from jedi>=0.16->ipython>=8.10.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (0.8.4)
# Requirement already satisfied: locket in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from partd>=1.4.0->dask>=2022.1.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (1.0.0)
# Requirement already satisfied: wcwidth in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=8.10.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from stack-data->ipython>=8.10.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from stack-data->ipython>=8.10.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\atosato\anaconda3\envs\qdrive\lib\site-packages (from stack-data->ipython>=8.10.0->qcodes>0.35.0->etiket-client->file_sync_example==0.1.0) (0.2.3)
# Building wheels for collected packages: file_sync_example
#   Building wheel for file_sync_example (pyproject.toml): started
#   Building wheel for file_sync_example (pyproject.toml): finished with status 'done'
#   Created wheel for file_sync_example: filename=file_sync_example-0.1.0-py3-none-any.whl size=3535 sha256=55414c1c75413b8956d5cd30b0d651859060774cc2e5fdb86b808588121d7c18
#   Stored in directory: C:\Users\atosato\AppData\Local\Temp\pip-ephem-wheel-cache-aq_nm_90\wheels\62\85\61\817dff0e318438059e57e1ef85300ea8125838a65379ca48cf
# Successfully built file_sync_example
# Installing collected packages: file_sync_example
#   Attempting uninstall: file_sync_example
#     Found existing installation: file_sync_example 0.1.0
#     Uninstalling file_sync_example-0.1.0:
#       Successfully uninstalled file_sync_example-0.1.0
# Successfully installed file_sync_example-0.1.0

# %% [markdown]
# ## Configuring and launching the synchronization agent
#
# Once the package is installed, it can be added to the synchronization agent as follows:

# %%
from etiket_client.sync.backends.sources import add_sync_source
from etiket_client.python_api.scopes import get_scope_by_name

from file_sync_example.config import FileSyncExampleConfig
from file_sync_example.sync import FileSyncExampleSync

import pathlib, os 

data_path = pathlib.Path(os.path.abspath(os.path.join(os.path.dirname(os.getcwd()), 'NQCP', 'data', 'sync_example_data')))

if not data_path.exists():
    raise ValueError(f"Data path {data_path} does not exist. Please correct the path.")

default_scope = get_scope_by_name('z_scope')

config = FileSyncExampleConfig(
	data_storage_location = data_path,
	set_up = "my_setup",
	sample_name= "DEV-05-0023"
)

add_sync_source('simple_sync', FileSyncExampleSync, config, default_scope)
